# %% [markdown]
# <h1>Nutritional Analysis of Convenience Food Options at Seven Eleven</h1>
#
# by David Diaz Aguirre
#
# <p>From onigiri to full bento boxes, Seven Eleven offers an incredibly large variety of food options at its more than 21,000 stores in Japan. This "convenience food" is a staple for those who live busy lives, and so Seven Eleven strives to provide options that are both convenient and tasty. While the customer certainly pays a premium for the convenience, for most, the prices are low enough to be affordable at least once in a while. However, how healthy are these food options really?</p>
# <p>Gym-goers in particular are careful about the nutritional value of the foods they eat, and try to minimize the amount of calories and fat they consume, while maximizing their protein intake. Given that fitness is a large time committment that requires getting enough exercise while also balancing work and other aspects of life, many people with this goal may turn to convenience food to supplement their diets.</p>
# <p>In this analysis, I will pull the nutritional information of Seven Eleven's food offerings in an attempt to understand which options may be more appealing to health-conscious consumers. As a primary analysis, it will be rather simple, but I will do this by comparing the caloric content of the food with its protein content. Given that lower calories for higher protein content is desirable for gym-goers, I will search for the food options that give the best ratio of protein-per-calories.</p>

# %% [markdown]
# <h2>Part 1: Scraping Nutritional Data from the Official Seven Eleven Website</h2>
#
# <p>First, I will use the `requests` library in Python to pull the web pages containing the individual product pages on Seven Eleven's website, and then I will use the `BeautifulSoup` library as well as regular expressions to parse the HTML content and extract the nutritional information that we are looking for.</p>
#
# <p>At this stage, due to time constraints, I will limit my scraping and analysis to only the Sandwiches available at Seven Eleven. This is because the inventory at Seven Eleven is truly immense, and analysis of all offerings would take considerably longer.</p>
# <p>As an aside, I have confirmed that scraping the product pages is allowed by Seven Eleven under their guidelines at https://www.sej.co.jp/robots.txt</p>

# %%
# Import the relevant libraries we will use for fetching and parsing the data
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import re

# %%
# Define the base url of the Seven Eleven website
BASE_URL = "https://www.sej.co.jp"

# This is the base URL for the Sandwich category of Seven Eleven's inventory
CATEGORY_BASE = "https://www.sej.co.jp/products/a/sandwich/"

# Declare ourselves to the Seven Eleven server
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Educational Data Project)"
}

# %%
# I will gather all the product links into this list
product_links = []

# Loop through pages 1 to 9, which is how many pages of sandwiches there are on the website
for page in range(1, 10):

    # Build the paginated URL and print so I see the progress
    url = f"{CATEGORY_BASE}{page}/l15/"
    print(f"Scraping category page: {url}")

    # Download the page
    res = requests.get(url, headers=HEADERS)

    # Parse the HTML so I can search it
    soup = BeautifulSoup(res.text, "html.parser")

    links_found_on_page = 0

    # Look through every <a> tag on the page
    for a in soup.select("a"):

        # Extract the href attribute
        href = a.get("href")

        # Only keep product links that follow the URL format on Seven Eleven's website
        if href and "/products/a/item/" in href:

            # Convert into a full URL
            full_url = BASE_URL + href

            # Add this product link to the list for scraping
            product_links.append(full_url)
            links_found_on_page += 1
    
    print(f"  Found {links_found_on_page} products on this page")

    # Stop scraping if no links are found on the page, in case the code does not work. Otherwise it will stop when it has scraped 9 pages
    if links_found_on_page == 0:
        break

    # Wait 1.5 seconds between iterations so as to not send all HTTP requests in quick succession
    time.sleep(1.5)

# Get the set of product links to remove duplicates just in case
product_links = list(set(product_links))

# There are 133 sandwiches listed on Seven Eleven's website, so I'll know this worked if this prints 133
print(f"TOTAL PRODUCTS FOUND: {len(product_links)}")
# Out:
# Scraping category page: https://www.sej.co.jp/products/a/sandwich/1/l15/
#   Found 30 products on this page
# Scraping category page: https://www.sej.co.jp/products/a/sandwich/2/l15/
#   Found 30 products on this page
# Scraping category page: https://www.sej.co.jp/products/a/sandwich/3/l15/
#   Found 30 products on this page
# Scraping category page: https://www.sej.co.jp/products/a/sandwich/4/l15/
#   Found 30 products on this page
# Scraping category page: https://www.sej.co.jp/products/a/sandwich/5/l15/
#   Found 30 products on this page
# Scraping category page: https://www.sej.co.jp/products/a/sandwich/6/l15/
#   Found 30 products on this page
# Scraping category page: https://www.sej.co.jp/products/a/sandwich/7/l15/
#   Found 30 products on this page
# Scraping category page: https://www.sej.co.jp/products/a/sandwich/8/l15/
#   Found 30 products on this page
# Scraping category page: https://www.sej.co.jp/products/a/sandwich/9/l15/
#   Found 26 products on this page
# TOTAL PRODUCTS FOUND: 133

# %% [markdown]
# <p>Now that we have all the product pages for all 133 sandwiches that Seven Eleven offers, I will access each page and extract the nutritional data in order to build the dataset.</p>

# %%
rows = []   # This will store each final product record

# This helper function will pull the nutritional values using regular expressions
def extract_value(pattern, text):
    if text is None:
        return None
    match = re.search(pattern, text)
    return float(match.group(1)) if match else None


# I will enumerate the product_links list in order to loop through it and use the index, starting from 1, to track the scraping progress
for i, url in enumerate(product_links, start=1):

    print(f"[{i}/{len(product_links)}] Scraping product: {url}")

    # Download the product page
    res = requests.get(url, headers=HEADERS)
    soup = BeautifulSoup(res.text, "html.parser")

    # Get the product name from the page header
    name_tag = soup.find("h1")
    product_name = name_tag.text.strip() if name_tag else None

    # The nutrition information is held in a single <td> in an HTML table for each product, so I will hold it here and append to rows later
    nutrition_text = None
    
    # Look for the row labeled 栄養成分 (nutritional information)
    for tr in soup.select("table tr"):
        th = tr.find("th")
        td = tr.find("td")
        
        if th and td and "栄養成分" in th.text:
            nutrition_text = td.text.strip()
            break

    # Extract each nutrient from the combined string. The regular exression `[\d\.]+` will capture strings of one or more digits and decimals, getting our nutrional value
    calories = extract_value(r"熱量：([\d\.]+)kcal", nutrition_text)
    protein  = extract_value(r"たんぱく質：([\d\.]+)g", nutrition_text)
    fat      = extract_value(r"脂質：([\d\.]+)g", nutrition_text)
    carbs    = extract_value(r"炭水化物：([\d\.]+)g", nutrition_text)

    # I will extract the prices too, although we are focusing on the nutritional value, this may be useful later
    # The Seven Eleven website keeps the prices in a div with class=="item_price" and then a nested <p> with the price in yen.
    price_tag = soup.select_one(".item_price p")
    price = price_tag.text.strip() if price_tag else None

    # Append everything in a structured format, creating a list of dictionaries that we can turn into a DataFrame
    rows.append({
        "store": "7-Eleven",
        "product_name": product_name,
        "calories": calories,
        "protein_g": protein,
        "fat_g": fat,
        "carbs_g": carbs,
        "price_yen": price,
        "url": url
    })

    # Small delay so as to not send too many requests at once
    time.sleep(1.5)
# Out:
# [1/133] Scraping product: https://www.sej.co.jp/products/a/item/052537/
# [2/133] Scraping product: https://www.sej.co.jp/products/a/item/053369/
# [3/133] Scraping product: https://www.sej.co.jp/products/a/item/052858/
# [4/133] Scraping product: https://www.sej.co.jp/products/a/item/053326/
# [5/133] Scraping product: https://www.sej.co.jp/products/a/item/053327/
# [6/133] Scraping product: https://www.sej.co.jp/products/a/item/052956/
# [7/133] Scraping product: https://www.sej.co.jp/products/a/item/053083/
# [8/133] Scraping product: https://www.sej.co.jp/products/a/item/052552/
# [9/133] Scraping product: https://www.sej.co.jp/products/a/item/052923/
# [10/133] Scraping product: https://www.sej.co.jp/products/a/item/053288/
# [11/133] Scraping product: https://www.sej.co.jp/products/a/item/053338/
# [12/133] Scraping product: https://www.sej.co.jp/products/a/item/053265/
# [13/133] Scraping product: https://www.sej.co.jp/products/a/item/052875/
# [14/133] Scraping product: https://www.sej.co.jp/products/a/item/053118/
# [15/133] Scraping product: https://www.sej.co.jp/products/a/item/052978/
# [16/133] Scraping product: https://www.sej.co.jp/products/a/item/053263/
# [17/133] Scraping product: https://www.sej.co.jp/products/a/item/052842/
# [18/133] Scraping product: https://www.sej.co.jp/products/a/item/053131/
# [19/133] Scraping product: https://www.sej.co.jp/products/a/item/053349/
# [20/133] Scraping product: https://www.sej.co.jp/products/a/item/053388/
# [21/133] Scraping product: https://www.sej.co.jp/products/a/item/052818/
# [22/133] Scraping product: https://www.sej.co.jp/products/a/item/053053/
# [23/133] Scraping product: https://www.sej.co.jp/products/a/item/053352/
# [24/133] Scraping product: https://www.sej.co.jp/products/a/item/051160/
# [25/133] Scraping product: https://www.sej.co.jp/products/a/item/053354/
# [26/133] Scraping product: https://www.sej.co.jp/products/a/item/053347/
# [27/133] Scraping product: https://www.sej.co.jp/products/a/item/052890/
# [28/133] Scraping product: https://www.sej.co.jp/products/a/item/052850/
# [29/133] Scraping product: https://www.sej.co.jp/products/a/item/053392/
# [30/133] Scraping product: https://www.sej.co.jp/products/a/item/052328/
# [31/133] Scraping product: https://www.sej.co.jp/products/a/item/053379/
# [32/133] Scraping product: https://www.sej.co.jp/products/a/item/053341/
# [33/133] Scraping product: https://www.sej.co.jp/products/a/item/053259/
# [34/133] Scraping product: https://www.sej.co.jp/products/a/item/053310/
# [35/133] Scraping product: https://www.sej.co.jp/products/a/item/053364/
# [36/133] Scraping product: https://www.sej.co.jp/products/a/item/052829/
# [37/133] Scraping product: https://www.sej.co.jp/products/a/item/053272/
# [38/133] Scraping product: https://www.sej.co.jp/products/a/item/053249/
# [39/133] Scraping product: https://www.sej.co.jp/products/a/item/053303/
# [40/133] Scraping product: https://www.sej.co.jp/products/a/item/053237/
# [41/133] Scraping product: https://www.sej.co.jp/products/a/item/053153/
# [42/133] Scraping product: https://www.sej.co.jp/products/a/item/053305/
# [43/133] Scraping product: https://www.sej.co.jp/products/a/item/053386/
# [44/133] Scraping product: https://www.sej.co.jp/products/a/item/053282/
# [45/133] Scraping product: https://www.sej.co.jp/products/a/item/053356/
# [46/133] Scraping product: https://www.sej.co.jp/products/a/item/052925/
# [47/133] Scraping product: https://www.sej.co.jp/products/a/item/053038/
# [48/133] Scraping product: https://www.sej.co.jp/products/a/item/053284/
# [49/133] Scraping product: https://www.sej.co.jp/products/a/item/052346/
# [50/133] Scraping product: https://www.sej.co.jp/products/a/item/053381/
# [51/133] Scraping product: https://www.sej.co.jp/products/a/item/053374/
# [52/133] Scraping product: https://www.sej.co.jp/products/a/item/053302/
# [53/133] Scraping product: https://www.sej.co.jp/products/a/item/053329/
# [54/133] Scraping product: https://www.sej.co.jp/products/a/item/053283/
# [55/133] Scraping product: https://www.sej.co.jp/products/a/item/053330/
# [56/133] Scraping product: https://www.sej.co.jp/products/a/item/053254/
# [57/133] Scraping product: https://www.sej.co.jp/products/a/item/053385/
# [58/133] Scraping product: https://www.sej.co.jp/products/a/item/053268/
# [59/133] Scraping product: https://www.sej.co.jp/products/a/item/053311/
# [60/133] Scraping product: https://www.sej.co.jp/products/a/item/052773/
# [61/133] Scraping product: https://www.sej.co.jp/products/a/item/053301/
# [62/133] Scraping product: https://www.sej.co.jp/products/a/item/052975/
# [63/133] Scraping product: https://www.sej.co.jp/products/a/item/053307/
# [64/133] Scraping product: https://www.sej.co.jp/products/a/item/053291/
# [65/133] Scraping product: https://www.sej.co.jp/products/a/item/053325/
# [66/133] Scraping product: https://www.sej.co.jp/products/a/item/053387/
# [67/133] Scraping product: https://www.sej.co.jp/products/a/item/053296/
# [68/133] Scraping product: https://www.sej.co.jp/products/a/item/053344/
# [69/133] Scraping product: https://www.sej.co.jp/products/a/item/053298/
# [70/133] Scraping product: https://www.sej.co.jp/products/a/item/053285/
# [71/133] Scraping product: https://www.sej.co.jp/products/a/item/053277/
# [72/133] Scraping product: https://www.sej.co.jp/products/a/item/053367/
# [73/133] Scraping product: https://www.sej.co.jp/products/a/item/053339/
# [74/133] Scraping product: https://www.sej.co.jp/products/a/item/053350/
# [75/133] Scraping product: https://www.sej.co.jp/products/a/item/053295/
# [76/133] Scraping product: https://www.sej.co.jp/products/a/item/053126/
# [77/133] Scraping product: https://www.sej.co.jp/products/a/item/053199/
# [78/133] Scraping product: https://www.sej.co.jp/products/a/item/053211/
# [79/133] Scraping product: https://www.sej.co.jp/products/a/item/053371/
# [80/133] Scraping product: https://www.sej.co.jp/products/a/item/052979/
# [81/133] Scraping product: https://www.sej.co.jp/products/a/item/052833/
# [82/133] Scraping product: https://www.sej.co.jp/products/a/item/053372/
# [83/133] Scraping product: https://www.sej.co.jp/products/a/item/053266/
# [84/133] Scraping product: https://www.sej.co.jp/products/a/item/053368/
# [85/133] Scraping product: https://www.sej.co.jp/products/a/item/053172/
# [86/133] Scraping product: https://www.sej.co.jp/products/a/item/052955/
# [87/133] Scraping product: https://www.sej.co.jp/products/a/item/053321/
# [88/133] Scraping product: https://www.sej.co.jp/products/a/item/053102/
# [89/133] Scraping product: https://www.sej.co.jp/products/a/item/053236/
# [90/133] Scraping product: https://www.sej.co.jp/products/a/item/053343/
# [91/133] Scraping product: https://www.sej.co.jp/products/a/item/053351/
# [92/133] Scraping product: https://www.sej.co.jp/products/a/item/053293/
# [93/133] Scraping product: https://www.sej.co.jp/products/a/item/052782/
# [94/133] Scraping product: https://www.sej.co.jp/products/a/item/053159/
# [95/133] Scraping product: https://www.sej.co.jp/products/a/item/053378/
# [96/133] Scraping product: https://www.sej.co.jp/products/a/item/053332/
# [97/133] Scraping product: https://www.sej.co.jp/products/a/item/053382/
# [98/133] Scraping product: https://www.sej.co.jp/products/a/item/051569/
# [99/133] Scraping product: https://www.sej.co.jp/products/a/item/053044/
# [100/133] Scraping product: https://www.sej.co.jp/products/a/item/053137/
# [101/133] Scraping product: https://www.sej.co.jp/products/a/item/053359/
# [102/133] Scraping product: https://www.sej.co.jp/products/a/item/053393/
# [103/133] Scraping product: https://www.sej.co.jp/products/a/item/053323/
# [104/133] Scraping product: https://www.sej.co.jp/products/a/item/053348/
# [105/133] Scraping product: https://www.sej.co.jp/products/a/item/052918/
# [106/133] Scraping product: https://www.sej.co.jp/products/a/item/053360/
# [107/133] Scraping product: https://www.sej.co.jp/products/a/item/053101/
# [108/133] Scraping product: https://www.sej.co.jp/products/a/item/053353/
# [109/133] Scraping product: https://www.sej.co.jp/products/a/item/053136/
# [110/133] Scraping product: https://www.sej.co.jp/products/a/item/053376/
# [111/133] Scraping product: https://www.sej.co.jp/products/a/item/050282/
# [112/133] Scraping product: https://www.sej.co.jp/products/a/item/053390/
# [113/133] Scraping product: https://www.sej.co.jp/products/a/item/052895/
# [114/133] Scraping product: https://www.sej.co.jp/products/a/item/053112/
# [115/133] Scraping product: https://www.sej.co.jp/products/a/item/052853/
# [116/133] Scraping product: https://www.sej.co.jp/products/a/item/053334/
# [117/133] Scraping product: https://www.sej.co.jp/products/a/item/053384/
# [118/133] Scraping product: https://www.sej.co.jp/products/a/item/052835/
# [119/133] Scraping product: https://www.sej.co.jp/products/a/item/053318/
# [120/133] Scraping product: https://www.sej.co.jp/products/a/item/052874/
# [121/133] Scraping product: https://www.sej.co.jp/products/a/item/053024/
# [122/133] Scraping product: https://www.sej.co.jp/products/a/item/053389/
# [123/133] Scraping product: https://www.sej.co.jp/products/a/item/053269/
# [124/133] Scraping product: https://www.sej.co.jp/products/a/item/053054/
# [125/133] Scraping product: https://www.sej.co.jp/products/a/item/052960/
# [126/133] Scraping product: https://www.sej.co.jp/products/a/item/053306/
# [127/133] Scraping product: https://www.sej.co.jp/products/a/item/053158/
# [128/133] Scraping product: https://www.sej.co.jp/products/a/item/053380/
# [129/133] Scraping product: https://www.sej.co.jp/products/a/item/053228/
# [130/133] Scraping product: https://www.sej.co.jp/products/a/item/050167/
# [131/133] Scraping product: https://www.sej.co.jp/products/a/item/053366/
# [132/133] Scraping product: https://www.sej.co.jp/products/a/item/053345/
# [133/133] Scraping product: https://www.sej.co.jp/products/a/item/052451/

# %%
# Checking that everything got extracted correctly
rows
# Out:
# [{'store': '7-Eleven',
#   'product_name': 'ホットドッグ',
#   'calories': 271.0,
#   'protein_g': 9.5,
#   'fat_g': 16.2,
#   'carbs_g': 22.3,
#   'price_yen': '180円（税込194.40円）',
#   'url': 'https://www.sej.co.jp/products/a/item/052537/'},
#  {'store': '7-Eleven',
#   'product_name': '福島県産あかつきもものホイップサンド',
#   'calories': 595.0,
#   'protein_g': 6.0,
#   'fat_g': 41.6,
#   'carbs_g': 49.7,
#   'price_yen': '360円（税込388.80円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053369/'},
#  {'store': '7-Eleven',
#   'product_name': 'たれチキンカツサンド',
#   'calories': 412.0,
#   'protein_g': 18.1,
#   'fat_g': 20.1,
#   'carbs_g': 40.5,
#   'price_yen': '380円（税込410.40円）',
#   'url': 'https://www.sej.co.jp/products/a/item/052858/'},
#  {'store': '7-Eleven',
#   'product_name': 'てりやきソースのチキンバーガー',
#   'calories': 411.0,
#   'protein_g': 26.4,
#   'fat_g': 19.5,
#   'carbs_g': 33.5,
#   'price_yen': '388円（税込419.04円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053326/'},
#  {'store': '7-Eleven',
#   'product_name': 'てりやきソースのチキンバーガー',
#   'calories': 411.0,
#   'protein_g': 26.4,
#   'fat_g': 19.5,
#   'carbs_g': 33.5,
#   'price_yen': '388円（税込419.04円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053327/'},
#  {'store': '7-Eleven',
#   'product_name': 'バゲットサンド\u3000パストラミ＆クリームチーズ',
#   'calories': 296.0,
#   'protein_g': 10.3,
#   'fat_g': 15.2,
#   'carbs_g': 30.2,
#   'price_yen': '298円（税込321.84円）',
#   'url': 'https://www.sej.co.jp/products/a/item/052956/'},
#  {'store': '7-Eleven',
#   'product_name': '野菜ミックスサンド',
#   'calories': 289.0,
#   'protein_g': 8.4,
#   'fat_g': 14.8,
#   'carbs_g': 31.6,
#   'price_yen': '330円（税込356.40円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053083/'},
#  {'store': '7-Eleven',
#   'product_name': '九州産華味鳥チーズチキンカツサンド',
#   'calories': 405.0,
#   'protein_g': 19.4,
#   'fat_g': 20.6,
#   'carbs_g': 36.5,
#   'price_yen': '398円（税込429.84円）',
#   'url': 'https://www.sej.co.jp/products/a/item/052552/'},
#  {'store': '7-Eleven',
#   'product_name': 'タルタル海老カツサンド',
#   'calories': 455.0,
#   'protein_g': 12.8,
#   'fat_g': 24.9,
#   'carbs_g': 45.8,
#   'price_yen': '398円（税込429.84円）',
#   'url': 'https://www.sej.co.jp/products/a/item/052923/'},
#  {'store': '7-Eleven',
#   'product_name': 'たれチキンカツサンド',
#   'calories': 413.0,
#   'protein_g': 17.6,
#   'fat_g': 20.0,
#   'carbs_g': 41.4,
#   'price_yen': '380円（税込410.40円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053288/'},
#  {'store': '7-Eleven',
#   'product_name': '群馬県産たまご使用ベーコンエッグサンド',
#   'calories': 381.0,
#   'protein_g': 13.6,
#   'fat_g': 26.1,
#   'carbs_g': 23.5,
#   'price_yen': '298円（税込321.84円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053338/'},
#  {'store': '7-Eleven',
#   'product_name': 'トーストサンド\u3000\u3000\u3000\u3000ハム＆チーズ',
#   'calories': 402.0,
#   'protein_g': 17.7,
#   'fat_g': 15.1,
#   'carbs_g': 49.5,
#   'price_yen': '348円（税込375.84円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053265/'},
#  {'store': '7-Eleven',
#   'product_name': 'ミックスサンド',
#   'calories': 287.0,
#   'protein_g': 10.9,
#   'fat_g': 14.1,
#   'carbs_g': 29.9,
#   'price_yen': '250円（税込270円）',
#   'url': 'https://www.sej.co.jp/products/a/item/052875/'},
#  {'store': '7-Eleven',
#   'product_name': 'ブリトーグリルチキン＆ヤンニョムチーズ',
#   'calories': 294.0,
#   'protein_g': 15.8,
#   'fat_g': 11.3,
#   'carbs_g': 33.0,
#   'price_yen': '340円（税込367.20円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053118/'},
#  {'store': '7-Eleven',
#   'product_name': '照焼チキンとたまごサンド',
#   'calories': 338.0,
#   'protein_g': 16.3,
#   'fat_g': 18.9,
#   'carbs_g': 26.3,
#   'price_yen': '320円（税込345.60円）',
#   'url': 'https://www.sej.co.jp/products/a/item/052978/'},
#  {'store': '7-Eleven',
#   'product_name': 'ひとくちサンドボックス\u3000ハム＆たまご',
#   'calories': 410.0,
#   'protein_g': 14.3,
#   'fat_g': 22.3,
#   'carbs_g': 39.2,
#   'price_yen': '418円（税込451.44円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053263/'},
#  {'store': '7-Eleven',
#   'product_name': '野菜ミックスサンド',
#   'calories': 287.0,
#   'protein_g': 8.5,
#   'fat_g': 14.4,
#   'carbs_g': 31.8,
#   'price_yen': '320円（税込345.60円）',
#   'url': 'https://www.sej.co.jp/products/a/item/052842/'},
#  {'store': '7-Eleven',
#   'product_name': 'チキンカツサンドからしマヨネーズ入り',
#   'calories': 423.0,
#   'protein_g': 17.6,
#   'fat_g': 21.3,
#   'carbs_g': 41.0,
#   'price_yen': '380円（税込410.40円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053131/'},
#  {'store': '7-Eleven',
#   'product_name': '野菜ミックスサンド',
#   'calories': 334.0,
#   'protein_g': 10.3,
#   'fat_g': 18.9,
#   'carbs_g': 31.6,
#   'price_yen': '330円（税込356.40円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053349/'},
#  {'store': '7-Eleven',
#   'product_name': 'シャキシャキレタスサンド',
#   'calories': 267.0,
#   'protein_g': 10.4,
#   'fat_g': 13.5,
#   'carbs_g': 26.9,
#   'price_yen': '328円（税込354.24円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053388/'},
#  {'store': '7-Eleven',
#   'product_name': 'チーズバーガー',
#   'calories': 320.0,
#   'protein_g': 13.9,
#   'fat_g': 13.3,
#   'carbs_g': 36.9,
#   'price_yen': '270円（税込291.60円）',
#   'url': 'https://www.sej.co.jp/products/a/item/052818/'},
#  {'store': '7-Eleven',
#   'product_name': 'ブリトーハム＆チーズ',
#   'calories': 271.0,
#   'protein_g': 15.7,
#   'fat_g': 11.2,
#   'carbs_g': 27.3,
#   'price_yen': '248円（税込267.84円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053053/'},
#  {'store': '7-Eleven',
#   'product_name': 'トマトと彩りミックスサンド',
#   'calories': 305.0,
#   'protein_g': 9.0,
#   'fat_g': 15.4,
#   'carbs_g': 33.9,
#   'price_yen': '348円（税込375.84円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053352/'},
#  {'store': '7-Eleven',
#   'product_name': 'トーストサンドハム＆チーズ',
#   'calories': 335.0,
#   'protein_g': 17.3,
#   'fat_g': 11.2,
#   'carbs_g': 42.1,
#   'price_yen': '238円（税込257.04円）',
#   'url': 'https://www.sej.co.jp/products/a/item/051160/'},
#  {'store': '7-Eleven',
#   'product_name': 'こだわりの旨みソーセージ\u3000ホットドッグ',
#   'calories': 263.0,
#   'protein_g': 9.2,
#   'fat_g': 15.4,
#   'carbs_g': 22.4,
#   'price_yen': '198円（税込213.84円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053354/'},
#  {'store': '7-Eleven',
#   'product_name': 'いちごソース＆ホイップクリームサンド',
#   'calories': 319.0,
#   'protein_g': 5.5,
#   'fat_g': 12.0,
#   'carbs_g': 47.9,
#   'price_yen': '250円（税込270円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053347/'},
#  {'store': '7-Eleven',
#   'product_name': 'ミックスサンド',
#   'calories': 287.0,
#   'protein_g': 10.9,
#   'fat_g': 14.1,
#   'carbs_g': 29.9,
#   'price_yen': '250円（税込270円）',
#   'url': 'https://www.sej.co.jp/products/a/item/052890/'},
#  {'store': '7-Eleven',
#   'product_name': '野菜ミックスサンド',
#   'calories': 337.0,
#   'protein_g': 10.2,
#   'fat_g': 19.2,
#   'carbs_g': 31.7,
#   'price_yen': '330円（税込356.40円）',
#   'url': 'https://www.sej.co.jp/products/a/item/052850/'},
#  {'store': '7-Eleven',
#   'product_name': '台湾ミンチドッグ',
#   'calories': 380.0,
#   'protein_g': 12.9,
#   'fat_g': 25.9,
#   'carbs_g': 24.3,
#   'price_yen': '298円（税込321.84円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053392/'},
#  {'store': '7-Eleven',
#   'product_name': 'ハムカツたまごサンド',
#   'calories': 461.0,
#   'protein_g': 12.2,
#   'fat_g': 28.3,
#   'carbs_g': 39.8,
#   'price_yen': '310円（税込334.80円）',
#   'url': 'https://www.sej.co.jp/products/a/item/052328/'},
#  {'store': '7-Eleven',
#   'product_name': 'チーズチキンカツロール',
#   'calories': 585.0,
#   'protein_g': 20.5,
#   'fat_g': 37.9,
#   'carbs_g': 41.2,
#   'price_yen': '290円（税込313.20円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053379/'},
#  {'store': '7-Eleven',
#   'product_name': 'コク旨たまごサラダロール',
#   'calories': 343.0,
#   'protein_g': 7.9,
#   'fat_g': 23.8,
#   'carbs_g': 24.9,
#   'price_yen': '168円（税込181.44円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053341/'},
#  {'store': '7-Eleven',
#   'product_name': 'ブリトーモッツァレラ\u3000とトマトのマルゲリ－タ',
#   'calories': 281.0,
#   'protein_g': 14.8,
#   'fat_g': 10.7,
#   'carbs_g': 32.2,
#   'price_yen': '288円（税込311.04円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053259/'},
#  {'store': '7-Eleven',
#   'product_name': 'ジューシーハムサンド',
#   'calories': 357.0,
#   'protein_g': 12.1,
#   'fat_g': 20.4,
#   'carbs_g': 32.0,
#   'price_yen': '328円（税込354.24円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053310/'},
#  {'store': '7-Eleven',
#   'product_name': 'ジャーマンポテトロール',
#   'calories': 310.0,
#   'protein_g': 11.5,
#   'fat_g': 14.9,
#   'carbs_g': 35.7,
#   'price_yen': '330円（税込356.40円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053364/'},
#  {'store': '7-Eleven',
#   'product_name': 'チーズバーガー',
#   'calories': 320.0,
#   'protein_g': 13.9,
#   'fat_g': 13.3,
#   'carbs_g': 36.9,
#   'price_yen': '270円（税込291.60円）',
#   'url': 'https://www.sej.co.jp/products/a/item/052829/'},
#  {'store': '7-Eleven',
#   'product_name': 'ハムカツたまごサンド',
#   'calories': 370.0,
#   'protein_g': 10.1,
#   'fat_g': 19.7,
#   'carbs_g': 39.0,
#   'price_yen': '280円（税込302.40円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053272/'},
#  {'store': '7-Eleven',
#   'product_name': 'ひとくちサンドボックスハム＆たまご',
#   'calories': 409.0,
#   'protein_g': 13.5,
#   'fat_g': 22.2,
#   'carbs_g': 39.8,
#   'price_yen': '418円（税込451.44円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053249/'},
#  {'store': '7-Eleven',
#   'product_name': '照焼チキンとたまごサンド',
#   'calories': 337.0,
#   'protein_g': 16.2,
#   'fat_g': 18.7,
#   'carbs_g': 26.8,
#   'price_yen': '328円（税込354.24円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053303/'},
#  {'store': '7-Eleven',
#   'product_name': 'クロワッサンサンド\u3000\u3000ハム＆チーズ',
#   'calories': 429.0,
#   'protein_g': 9.3,
#   'fat_g': 34.0,
#   'carbs_g': 22.1,
#   'price_yen': '398円（税込429.84円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053237/'},
#  {'store': '7-Eleven',
#   'product_name': 'ハムとたまごのサンド',
#   'calories': 337.0,
#   'protein_g': 11.8,
#   'fat_g': 19.3,
#   'carbs_g': 29.7,
#   'price_yen': '310円（税込334.80円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053153/'},
#  {'store': '7-Eleven',
#   'product_name': 'ハムカツたまごサンド',
#   'calories': 371.0,
#   'protein_g': 10.3,
#   'fat_g': 19.7,
#   'carbs_g': 39.1,
#   'price_yen': '280円（税込302.40円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053305/'},
#  {'store': '7-Eleven',
#   'product_name': 'セブンーイレブンこだわりＴＨＥたまごサンド',
#   'calories': 385.0,
#   'protein_g': 11.2,
#   'fat_g': 27.5,
#   'carbs_g': 23.7,
#   'price_yen': '270円（税込291.60円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053386/'},
#  {'store': '7-Eleven',
#   'product_name': '佐世保スイートマヨサンド',
#   'calories': 494.0,
#   'protein_g': 10.2,
#   'fat_g': 33.5,
#   'carbs_g': 38.8,
#   'price_yen': '528円（税込570.24円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053282/'},
#  {'store': '7-Eleven',
#   'product_name': 'コーンとベーコンのクリームソース',
#   'calories': 282.0,
#   'protein_g': 10.5,
#   'fat_g': 12.4,
#   'carbs_g': 33.6,
#   'price_yen': '298円（税込321.84円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053356/'},
#  {'store': '7-Eleven',
#   'product_name': 'タルタル海老カツサンド',
#   'calories': 457.0,
#   'protein_g': 12.8,
#   'fat_g': 25.1,
#   'carbs_g': 45.9,
#   'price_yen': '398円（税込429.84円）',
#   'url': 'https://www.sej.co.jp/products/a/item/052925/'},
#  {'store': '7-Eleven',
#   'product_name': 'タルタル海老カツサンド',
#   'calories': 457.0,
#   'protein_g': 12.8,
#   'fat_g': 25.1,
#   'carbs_g': 45.9,
#   'price_yen': '398円（税込429.84円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053038/'},
#  {'store': '7-Eleven',
#   'product_name': 'クロワッサンサンド\u3000\u3000パストラミビーフ',
#   'calories': 332.0,
#   'protein_g': 9.5,
#   'fat_g': 23.1,
#   'carbs_g': 22.2,
#   'price_yen': '398円（税込429.84円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053284/'},
#  {'store': '7-Eleven',
#   'product_name': 'バゲットサンド\u3000ベーコン＆北海道産クリームチーズ',
#   'calories': 334.0,
#   'protein_g': 9.0,
#   'fat_g': 20.7,
#   'carbs_g': 28.7,
#   'price_yen': '260円（税込280.80円）',
#   'url': 'https://www.sej.co.jp/products/a/item/052346/'},
#  {'store': '7-Eleven',
#   'product_name': 'あんホイップサンド',
#   'calories': 303.0,
#   'protein_g': 5.8,
#   'fat_g': 14.7,
#   'carbs_g': 38.9,
#   'price_yen': '250円（税込270円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053381/'},
#  {'store': '7-Eleven',
#   'product_name': 'ひとくちフレンチトースト',
#   'calories': 371.0,
#   'protein_g': 10.3,
#   'fat_g': 16.4,
#   'carbs_g': 46.2,
#   'price_yen': '250円（税込270円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053374/'},
#  {'store': '7-Eleven',
#   'product_name': 'チキンカツサンド',
#   'calories': 413.0,
#   'protein_g': 17.8,
#   'fat_g': 20.1,
#   'carbs_g': 41.2,
#   'price_yen': '388円（税込419.04円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053302/'},
#  {'store': '7-Eleven',
#   'product_name': 'ソーセージエッグマフィン',
#   'calories': 382.0,
#   'protein_g': 19.0,
#   'fat_g': 20.4,
#   'carbs_g': 31.7,
#   'price_yen': '278円（税込300.24円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053329/'},
#  {'store': '7-Eleven',
#   'product_name': '野菜ミックスサンド',
#   'calories': 313.0,
#   'protein_g': 9.5,
#   'fat_g': 16.7,
#   'carbs_g': 32.2,
#   'price_yen': '348円（税込375.84円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053283/'},
#  {'store': '7-Eleven',
#   'product_name': 'コク旨たまごサラダロール',
#   'calories': 343.0,
#   'protein_g': 7.9,
#   'fat_g': 23.8,
#   'carbs_g': 24.9,
#   'price_yen': '168円（税込181.44円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053330/'},
#  {'store': '7-Eleven',
#   'product_name': 'たんぱく質が摂れるチキンロール',
#   'calories': 245.0,
#   'protein_g': 28.0,
#   'fat_g': 5.4,
#   'carbs_g': 22.7,
#   'price_yen': '390円（税込421.20円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053254/'},
#  {'store': '7-Eleven',
#   'product_name': 'スモークサーモン＆ブロッコリータルタル',
#   'calories': 277.0,
#   'protein_g': 11.5,
#   'fat_g': 16.1,
#   'carbs_g': 22.4,
#   'price_yen': '380円（税込410.40円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053385/'},
#  {'store': '7-Eleven',
#   'product_name': 'ソーセージエッグマフィン',
#   'calories': 355.0,
#   'protein_g': 14.6,
#   'fat_g': 18.9,
#   'carbs_g': 32.2,
#   'price_yen': '278円（税込300.24円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053268/'},
#  {'store': '7-Eleven',
#   'product_name': 'ジューシーハムサンド',
#   'calories': 359.0,
#   'protein_g': 12.4,
#   'fat_g': 20.4,
#   'carbs_g': 32.3,
#   'price_yen': '330円（税込356.40円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053311/'},
#  {'store': '7-Eleven',
#   'product_name': '全粒粉バゲット\u3000生ハム＆トマト',
#   'calories': 289.0,
#   'protein_g': 11.5,
#   'fat_g': 12.1,
#   'carbs_g': 34.7,
#   'price_yen': '340円（税込367.20円）',
#   'url': 'https://www.sej.co.jp/products/a/item/052773/'},
#  {'store': '7-Eleven',
#   'product_name': 'ツナ＆きゅうりサンド',
#   'calories': 327.0,
#   'protein_g': 12.6,
#   'fat_g': 19.7,
#   'carbs_g': 25.7,
#   'price_yen': '320円（税込345.60円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053301/'},
#  {'store': '7-Eleven',
#   'product_name': '照焼チキンとたまごサンド',
#   'calories': 338.0,
#   'protein_g': 16.3,
#   'fat_g': 18.9,
#   'carbs_g': 26.3,
#   'price_yen': '320円（税込345.60円）',
#   'url': 'https://www.sej.co.jp/products/a/item/052975/'},
#  {'store': '7-Eleven',
#   'product_name': 'ハム＆たまごサンド',
#   'calories': 343.0,
#   'protein_g': 12.3,
#   'fat_g': 19.3,
#   'carbs_g': 31.0,
#   'price_yen': '320円（税込345.60円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053307/'},
#  {'store': '7-Eleven',
#   'product_name': 'スタミナ源たれソースのチキンバーガー',
#   'calories': 372.0,
#   'protein_g': 26.4,
#   'fat_g': 16.9,
#   'carbs_g': 29.4,
#   'price_yen': '380円（税込410.40円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053291/'},
#  {'store': '7-Eleven',
#   'product_name': '玉子焼きミックスサンド',
#   'calories': 353.0,
#   'protein_g': 11.5,
#   'fat_g': 20.1,
#   'carbs_g': 32.3,
#   'price_yen': '390円（税込421.20円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053325/'},
#  {'store': '7-Eleven',
#   'product_name': 'シャキシャキレタスサンド',
#   'calories': 262.0,
#   'protein_g': 10.4,
#   'fat_g': 13.1,
#   'carbs_g': 26.6,
#   'price_yen': '318円（税込343.44円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053387/'},
#  {'store': '7-Eleven',
#   'product_name': 'ひとくちサンドボックス\u3000ハム＆たまご',
#   'calories': 412.0,
#   'protein_g': 13.9,
#   'fat_g': 22.3,
#   'carbs_g': 40.2,
#   'price_yen': '418円（税込451.44円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053296/'},
#  {'store': '7-Eleven',
#   'product_name': 'ミニロール\u3000（ハンバーグ＆グラタン）',
#   'calories': 293.0,
#   'protein_g': 11.8,
#   'fat_g': 11.0,
#   'carbs_g': 38.0,
#   'price_yen': '300円（税込324円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053344/'},
#  {'store': '7-Eleven',
#   'product_name': '１組ガブっと相盛サンド\u3000メンチカツ＆たまご',
#   'calories': 372.0,
#   'protein_g': 9.8,
#   'fat_g': 23.3,
#   'carbs_g': 31.7,
#   'price_yen': '250円（税込270円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053298/'},
#  {'store': '7-Eleven',
#   'product_name': '九州産華味鳥チキンカツサンド\u3000和風醤油だれ',
#   'calories': 434.0,
#   'protein_g': 18.6,
#   'fat_g': 21.8,
#   'carbs_g': 41.8,
#   'price_yen': '380円（税込410.40円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053285/'},
#  {'store': '7-Eleven',
#   'product_name': 'ハムカツたまごサンド',
#   'calories': 372.0,
#   'protein_g': 10.6,
#   'fat_g': 19.8,
#   'carbs_g': 38.9,
#   'price_yen': '280円（税込302.40円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053277/'},
#  {'store': '7-Eleven',
#   'product_name': 'もも・ももサンド',
#   'calories': 275.0,
#   'protein_g': 5.3,
#   'fat_g': 11.9,
#   'carbs_g': 37.5,
#   'price_yen': '380円（税込410.40円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053367/'},
#  {'store': '7-Eleven',
#   'product_name': '茨城県産たまご使用ベーコンエッグサンド',
#   'calories': 337.0,
#   'protein_g': 13.6,
#   'fat_g': 25.8,
#   'carbs_g': 23.3,
#   'price_yen': '298円（税込321.84円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053339/'},
#  {'store': '7-Eleven',
#   'product_name': 'ホットドッグ\u3000カレーキャベツ盛り',
#   'calories': 286.0,
#   'protein_g': 8.9,
#   'fat_g': 16.9,
#   'carbs_g': 25.1,
#   'price_yen': '230円（税込248.40円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053350/'},
#  {'store': '7-Eleven',
#   'product_name': 'ラップデリ\u3000直火焼き\u3000ケバブ風チキン',
#   'calories': 361.0,
#   'protein_g': 15.8,
#   'fat_g': 22.2,
#   'carbs_g': 25.5,
#   'price_yen': '298円（税込321.84円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053295/'},
#  {'store': '7-Eleven',
#   'product_name': 'チキンカツサンド\u3000からしマヨネーズ入り',
#   'calories': 423.0,
#   'protein_g': 17.6,
#   'fat_g': 21.3,
#   'carbs_g': 41.0,
#   'price_yen': '380円（税込410.40円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053126/'},
#  {'store': '7-Eleven',
#   'product_name': '野菜ミックスサンド',
#   'calories': 334.0,
#   'protein_g': 8.9,
#   'fat_g': 18.6,
#   'carbs_g': 33.8,
#   'price_yen': '360円（税込388.80円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053199/'},
#  {'store': '7-Eleven',
#   'product_name': 'ペッパーポーク＆チェダー',
#   'calories': 322.0,
#   'protein_g': 13.1,
#   'fat_g': 16.0,
#   'carbs_g': 32.6,
#   'price_yen': '378円（税込408.24円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053211/'},
#  {'store': '7-Eleven',
#   'product_name': 'バゲットサンド\u3000ベーコン＆クリームチーズ',
#   'calories': 347.0,
#   'protein_g': 8.9,
#   'fat_g': 22.3,
#   'carbs_g': 28.5,
#   'price_yen': '298円（税込321.84円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053371/'},
#  {'store': '7-Eleven',
#   'product_name': '照焼チキンとたまごサンド',
#   'calories': 338.0,
#   'protein_g': 16.3,
#   'fat_g': 18.9,
#   'carbs_g': 26.3,
#   'price_yen': '320円（税込345.60円）',
#   'url': 'https://www.sej.co.jp/products/a/item/052979/'},
#  {'store': '7-Eleven',
#   'product_name': 'チーズバーガー',
#   'calories': 320.0,
#   'protein_g': 13.9,
#   'fat_g': 13.3,
#   'carbs_g': 36.9,
#   'price_yen': '270円（税込291.60円）',
#   'url': 'https://www.sej.co.jp/products/a/item/052833/'},
#  {'store': '7-Eleven',
#   'product_name': '静岡限定シーチキンサラダロール',
#   'calories': 257.0,
#   'protein_g': 9.2,
#   'fat_g': 13.9,
#   'carbs_g': 24.2,
#   'price_yen': '178円（税込192.24円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053372/'},
#  {'store': '7-Eleven',
#   'product_name': '九州産華味鳥チーズチキンカツサンド',
#   'calories': 406.0,
#   'protein_g': 19.4,
#   'fat_g': 20.6,
#   'carbs_g': 36.8,
#   'price_yen': '398円（税込429.84円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053266/'},
#  {'store': '7-Eleven',
#   'product_name': 'アメリカンクラブハウスサンド',
#   'calories': 389.0,
#   'protein_g': 14.2,
#   'fat_g': 23.7,
#   'carbs_g': 30.8,
#   'price_yen': '478円（税込516.24円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053368/'},
#  {'store': '7-Eleven',
#   'product_name': 'ハムとたまごのサンド',
#   'calories': 337.0,
#   'protein_g': 11.8,
#   'fat_g': 19.3,
#   'carbs_g': 29.7,
#   'price_yen': '310円（税込334.80円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053172/'},
#  {'store': '7-Eleven',
#   'product_name': 'バゲットサンド\u3000パストラミ＆クリームチーズ',
#   'calories': 296.0,
#   'protein_g': 10.3,
#   'fat_g': 15.2,
#   'carbs_g': 30.2,
#   'price_yen': '298円（税込321.84円）',
#   'url': 'https://www.sej.co.jp/products/a/item/052955/'},
#  {'store': '7-Eleven',
#   'product_name': 'ジューシーハムサンド',
#   'calories': 357.0,
#   'protein_g': 12.1,
#   'fat_g': 20.4,
#   'carbs_g': 32.0,
#   'price_yen': '328円（税込354.24円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053321/'},
#  {'store': '7-Eleven',
#   'product_name': 'チーズバーガー',
#   'calories': 382.0,
#   'protein_g': 15.4,
#   'fat_g': 16.9,
#   'carbs_g': 42.9,
#   'price_yen': '250円（税込270円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053102/'},
#  {'store': '7-Eleven',
#   'product_name': 'クロワッサンサンド\u3000パストラミポーク',
#   'calories': 390.0,
#   'protein_g': 11.5,
#   'fat_g': 27.2,
#   'carbs_g': 25.6,
#   'price_yen': '498円（税込537.84円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053236/'},
#  {'store': '7-Eleven',
#   'product_name': 'たんぱく質が摂れるチキン＆チリ',
#   'calories': 280.0,
#   'protein_g': 25.8,
#   'fat_g': 9.6,
#   'carbs_g': 24.8,
#   'price_yen': '400円（税込432円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053343/'},
#  {'store': '7-Eleven',
#   'product_name': 'もも・ももサンド\u3000榛名牛乳使用',
#   'calories': 265.0,
#   'protein_g': 5.0,
#   'fat_g': 11.2,
#   'carbs_g': 36.9,
#   'price_yen': '380円（税込410.40円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053351/'},
#  {'store': '7-Eleven',
#   'product_name': 'ジューシーハムサンド',
#   'calories': 361.0,
#   'protein_g': 12.2,
#   'fat_g': 20.2,
#   'carbs_g': 33.4,
#   'price_yen': '328円（税込354.24円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053293/'},
#  {'store': '7-Eleven',
#   'product_name': '久留米ホットドッグ',
#   'calories': 301.0,
#   'protein_g': 8.9,
#   'fat_g': 16.3,
#   'carbs_g': 31.2,
#   'price_yen': '218円（税込235.44円）',
#   'url': 'https://www.sej.co.jp/products/a/item/052782/'},
#  {'store': '7-Eleven',
#   'product_name': 'ハムとたまごのサンド',
#   'calories': 340.0,
#   'protein_g': 11.9,
#   'fat_g': 19.4,
#   'carbs_g': 30.1,
#   'price_yen': '310円（税込334.80円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053159/'},
#  {'store': '7-Eleven',
#   'product_name': 'セブンイレブンこだわりＴＨＥたまごサンド',
#   'calories': 385.0,
#   'protein_g': 11.2,
#   'fat_g': 27.5,
#   'carbs_g': 23.7,
#   'price_yen': '270円（税込291.60円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053378/'},
#  {'store': '7-Eleven',
#   'product_name': 'ハム＆ソフトサラミサンド',
#   'calories': 494.0,
#   'protein_g': 14.7,
#   'fat_g': 30.2,
#   'carbs_g': 42.0,
#   'price_yen': '418円（税込451.44円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053332/'},
#  {'store': '7-Eleven',
#   'product_name': '王様トマトの野菜ミックスサンド',
#   'calories': 317.0,
#   'protein_g': 9.6,
#   'fat_g': 16.4,
#   'carbs_g': 33.9,
#   'price_yen': '348円（税込375.84円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053382/'},
#  {'store': '7-Eleven',
#   'product_name': 'トーストサンドハム＆スクランブルエッグ',
#   'calories': 399.0,
#   'protein_g': 18.0,
#   'fat_g': 16.6,
#   'carbs_g': 45.5,
#   'price_yen': '268円（税込289.44円）',
#   'url': 'https://www.sej.co.jp/products/a/item/051569/'},
#  {'store': '7-Eleven',
#   'product_name': 'ミニロール（ハムたまご＆コロッケ）',
#   'calories': 307.0,
#   'protein_g': 8.4,
#   'fat_g': 13.7,
#   'carbs_g': 38.5,
#   'price_yen': '250円（税込270円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053044/'},
#  {'store': '7-Eleven',
#   'product_name': 'ミニロール（たまご＆ハムチーズ）',
#   'calories': 306.0,
#   'protein_g': 9.0,
#   'fat_g': 17.1,
#   'carbs_g': 29.9,
#   'price_yen': '240円（税込259.20円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053137/'},
#  {'store': '7-Eleven',
#   'product_name': 'チーズグラニュートースト',
#   'calories': 389.0,
#   'protein_g': 12.0,
#   'fat_g': 18.3,
#   'carbs_g': 44.7,
#   'price_yen': '278円（税込300.24円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053359/'},
#  {'store': '7-Eleven',
#   'product_name': '静岡限定シーチキン＆きゅうりサラダサンド',
#   'calories': 370.0,
#   'protein_g': 12.3,
#   'fat_g': 23.6,
#   'carbs_g': 27.9,
#   'price_yen': '320円（税込345.60円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053393/'},
#  {'store': '7-Eleven',
#   'product_name': '九州産華味鳥チキンカツバーガー',
#   'calories': 514.0,
#   'protein_g': 18.7,
#   'fat_g': 28.2,
#   'carbs_g': 47.6,
#   'price_yen': '370円（税込399.60円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053323/'},
#  {'store': '7-Eleven',
#   'product_name': 'ツナサラダロール',
#   'calories': 295.0,
#   'protein_g': 6.8,
#   'fat_g': 19.0,
#   'carbs_g': 24.9,
#   'price_yen': '148円（税込159.84円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053348/'},
#  {'store': '7-Eleven',
#   'product_name': 'たまごサンド',
#   'calories': 368.0,
#   'protein_g': 11.4,
#   'fat_g': 26.4,
#   'carbs_g': 21.8,
#   'price_yen': '230円（税込248.40円）',
#   'url': 'https://www.sej.co.jp/products/a/item/052918/'},
#  {'store': '7-Eleven',
#   'product_name': 'うま塩ペッパーチキンバーガー',
#   'calories': 391.0,
#   'protein_g': 26.6,
#   'fat_g': 20.1,
#   'carbs_g': 26.8,
#   'price_yen': '350円（税込378円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053360/'},
#  {'store': '7-Eleven',
#   'product_name': 'ツナ＆きゅうりサンド',
#   'calories': 323.0,
#   'protein_g': 13.1,
#   'fat_g': 19.1,
#   'carbs_g': 25.7,
#   'price_yen': '320円（税込345.60円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053101/'},
#  {'store': '7-Eleven',
#   'product_name': 'トマトと彩りミックスサンド',
#   'calories': 304.0,
#   'protein_g': 8.7,
#   'fat_g': 15.4,
#   'carbs_g': 33.6,
#   'price_yen': '340円（税込367.20円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053353/'},
#  {'store': '7-Eleven',
#   'product_name': 'ミニロール（たまご＆ハムチーズ）',
#   'calories': 306.0,
#   'protein_g': 9.0,
#   'fat_g': 17.1,
#   'carbs_g': 29.9,
#   'price_yen': '240円（税込259.20円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053136/'},
#  {'store': '7-Eleven',
#   'product_name': 'ミニロール（サーモンメンチ＆たまご）',
#   'calories': 356.0,
#   'protein_g': 8.9,
#   'fat_g': 19.8,
#   'carbs_g': 36.6,
#   'price_yen': '260円（税込280.80円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053376/'},
#  {'store': '7-Eleven',
#   'product_name': 'シャキシャキレタスサンド',
#   'calories': 264.0,
#   'protein_g': 10.4,
#   'fat_g': 13.3,
#   'carbs_g': 26.7,
#   'price_yen': '318円（税込343.44円）',
#   'url': 'https://www.sej.co.jp/products/a/item/050282/'},
#  {'store': '7-Eleven',
#   'product_name': 'ごちそうサンド\u3000ロースとんかつ',
#   'calories': 684.0,
#   'protein_g': 27.0,
#   'fat_g': 32.8,
#   'carbs_g': 71.9,
#   'price_yen': '498円（税込537.84円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053390/'},
#  {'store': '7-Eleven',
#   'product_name': 'たまご＆ツナサンド',
#   'calories': 338.0,
#   'protein_g': 10.6,
#   'fat_g': 21.9,
#   'carbs_g': 25.4,
#   'price_yen': '250円（税込270円）',
#   'url': 'https://www.sej.co.jp/products/a/item/052895/'},
#  {'store': '7-Eleven',
#   'product_name': 'ツナ＆きゅうりサンド',
#   'calories': 326.0,
#   'protein_g': 12.6,
#   'fat_g': 19.6,
#   'carbs_g': 25.7,
#   'price_yen': '320円（税込345.60円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053112/'},
#  {'store': '7-Eleven',
#   'product_name': 'ミックスサンド',
#   'calories': 288.0,
#   'protein_g': 11.2,
#   'fat_g': 14.0,
#   'carbs_g': 30.3,
#   'price_yen': '250円（税込270円）',
#   'url': 'https://www.sej.co.jp/products/a/item/052853/'},
#  {'store': '7-Eleven',
#   'product_name': 'ハム＆ソフトサラミサンド',
#   'calories': 494.0,
#   'protein_g': 14.7,
#   'fat_g': 30.2,
#   'carbs_g': 42.0,
#   'price_yen': '418円（税込451.44円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053334/'},
#  {'store': '7-Eleven',
#   'product_name': 'ブリトーＭＡＴＣＨＡあずきもち',
#   'calories': 256.0,
#   'protein_g': 7.6,
#   'fat_g': 5.9,
#   'carbs_g': 44.3,
#   'price_yen': '288円（税込311.04円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053384/'},
#  {'store': '7-Eleven',
#   'product_name': 'チーズバーガー',
#   'calories': 320.0,
#   'protein_g': 13.9,
#   'fat_g': 13.3,
#   'carbs_g': 36.9,
#   'price_yen': '270円（税込291.60円）',
#   'url': 'https://www.sej.co.jp/products/a/item/052835/'},
#  {'store': '7-Eleven',
#   'product_name': 'トーストサンドハム＆チーズ',
#   'calories': 371.0,
#   'protein_g': 16.6,
#   'fat_g': 14.0,
#   'carbs_g': 45.5,
#   'price_yen': '310円（税込334.80円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053318/'},
#  {'store': '7-Eleven',
#   'product_name': 'たまご＆ツナサンド',
#   'calories': 338.0,
#   'protein_g': 10.6,
#   'fat_g': 21.9,
#   'carbs_g': 25.4,
#   'price_yen': '250円（税込270円）',
#   'url': 'https://www.sej.co.jp/products/a/item/052874/'},
#  {'store': '7-Eleven',
#   'product_name': 'とんかつサンド',
#   'calories': 698.0,
#   'protein_g': 18.9,
#   'fat_g': 35.4,
#   'carbs_g': 77.1,
#   'price_yen': '420円（税込453.60円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053024/'},
#  {'store': '7-Eleven',
#   'product_name': 'セブンーイレブンこだわりＴＨＥたまごサンド',
#   'calories': 380.0,
#   'protein_g': 11.0,
#   'fat_g': 26.8,
#   'carbs_g': 24.4,
#   'price_yen': '270円（税込291.60円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053389/'},
#  {'store': '7-Eleven',
#   'product_name': 'ミックスサンド',
#   'calories': 307.0,
#   'protein_g': 10.7,
#   'fat_g': 16.2,
#   'carbs_g': 30.3,
#   'price_yen': '280円（税込302.40円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053269/'},
#  {'store': '7-Eleven',
#   'product_name': 'ブリトーチーズ倍盛り\u3000ハム＆チーズ',
#   'calories': 441.0,
#   'protein_g': 28.0,
#   'fat_g': 23.4,
#   'carbs_g': 31.1,
#   'price_yen': '390円（税込421.20円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053054/'},
#  {'store': '7-Eleven',
#   'product_name': 'ミニロール（たまご＆ハム）',
#   'calories': 307.0,
#   'protein_g': 9.3,
#   'fat_g': 17.2,
#   'carbs_g': 29.6,
#   'price_yen': '240円（税込259.20円）',
#   'url': 'https://www.sej.co.jp/products/a/item/052960/'},
#  {'store': '7-Eleven',
#   'product_name': 'ミックスサンド',
#   'calories': 289.0,
#   'protein_g': 11.0,
#   'fat_g': 14.0,
#   'carbs_g': 30.6,
#   'price_yen': '260円（税込280.80円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053306/'},
#  {'store': '7-Eleven',
#   'product_name': 'タルタルチキンバーガー',
#   'calories': 425.0,
#   'protein_g': 26.9,
#   'fat_g': 21.6,
#   'carbs_g': 31.8,
#   'price_yen': '378円（税込408.24円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053158/'},
#  {'store': '7-Eleven',
#   'product_name': '有田みかんサンド',
#   'calories': 213.0,
#   'protein_g': 3.3,
#   'fat_g': 11.4,
#   'carbs_g': 24.7,
#   'price_yen': '298円（税込321.84円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053380/'},
#  {'store': '7-Eleven',
#   'product_name': 'もも・ももサンド',
#   'calories': 280.0,
#   'protein_g': 5.1,
#   'fat_g': 12.5,
#   'carbs_g': 37.6,
#   'price_yen': '380円（税込410.40円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053228/'},
#  {'store': '7-Eleven',
#   'product_name': 'トーストサンド\u3000ＢＬＴ',
#   'calories': 458.0,
#   'protein_g': 15.1,
#   'fat_g': 26.5,
#   'carbs_g': 41.6,
#   'price_yen': '388円（税込419.04円）',
#   'url': 'https://www.sej.co.jp/products/a/item/050167/'},
#  {'store': '7-Eleven',
#   'product_name': 'アメリカンクラブハウスサンド',
#   'calories': 403.0,
#   'protein_g': 15.1,
#   'fat_g': 25.0,
#   'carbs_g': 30.5,
#   'price_yen': '478円（税込516.24円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053366/'},
#  {'store': '7-Eleven',
#   'product_name': 'クロワッサンサンド照焼チキン＆たまご',
#   'calories': 429.0,
#   'protein_g': 14.2,
#   'fat_g': 27.8,
#   'carbs_g': 31.2,
#   'price_yen': '390円（税込421.20円）',
#   'url': 'https://www.sej.co.jp/products/a/item/053345/'},
#  {'store': '7-Eleven',
#   'product_name': 'たんぱく質が摂れるチキンロール',
#   'calories': 245.0,
#   'protein_g': 28.0,
#   'fat_g': 5.4,
#   'carbs_g': 22.7,
#   'price_yen': '390円（税込421.20円）',
#   'url': 'https://www.sej.co.jp/products/a/item/052451/'}]

# %% [markdown]
# <p>Now that I scraped all the pages and got the necessary information out of it, I can turn it all into a pandas DataFrame for cleaning and analysis.</p>

# %%
df = pd.DataFrame(rows)
df.head()
# Out:
#       store        product_name  calories  protein_g  fat_g  carbs_g  \
# 0  7-Eleven              ホットドッグ     271.0        9.5   16.2     22.3
# 1  7-Eleven  福島県産あかつきもものホイップサンド     595.0        6.0   41.6     49.7
# 2  7-Eleven          たれチキンカツサンド     412.0       18.1   20.1     40.5
# 3  7-Eleven     てりやきソースのチキンバーガー     411.0       26.4   19.5     33.5
# 4  7-Eleven     てりやきソースのチキンバーガー     411.0       26.4   19.5     33.5
#
#          price_yen                                            url
# 0  180円（税込194.40円）  https://www.sej.co.jp/products/a/item/052537/
# 1  360円（税込388.80円）  https://www.sej.co.jp/products/a/item/053369/
# 2  380円（税込410.40円）  https://www.sej.co.jp/products/a/item/052858/
# 3  388円（税込419.04円）  https://www.sej.co.jp/products/a/item/053326/
# 4  388円（税込419.04円）  https://www.sej.co.jp/products/a/item/053327/

# %% [markdown]
# <h2>Part 2: Cleaning and Gaining Insights from the Data</h2>

# %%
# First I'll check the data types. I'm going to need to clean the prices for sure
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   store         133 non-null    object
#  1   product_name  133 non-null    object
#  2   calories      133 non-null    float64
#  3   protein_g     133 non-null    float64
#  4   fat_g         133 non-null    float64
#  5   carbs_g       133 non-null    float64
#  6   price_yen     133 non-null    object
#  7   url           133 non-null    object
# dtypes: float64(4), object(4)
# memory usage: 8.4+ KB

# %%
# I'll turn the prices into floats by only keeping the pre-tax price
df["price_yen"] = df["price_yen"].str.extract(r"^([\d]+)円").astype(float)
df["price_yen"].dtype
# Out:
# dtype('float64')

# %% [markdown]
# Now, let's compare the sandwiches to find which have the best **calorie-to-protein** and **price-to-protein** ratio.

# %%
# Protein efficiency
df["protein_per_100kcal"] = df["protein_g"] / df["calories"] * 100

# Protein per yen
df["protein_per_yen"] = df["protein_g"] / df["price_yen"]

display(df.sort_values("protein_per_100kcal", ascending=False).head(5))
display(df.sort_values("protein_per_yen", ascending=False).head(5))
# Out:
#         store        product_name  calories  protein_g  fat_g  carbs_g  \
# 132  7-Eleven     たんぱく質が摂れるチキンロール     245.0       28.0    5.4     22.7
# 55   7-Eleven     たんぱく質が摂れるチキンロール     245.0       28.0    5.4     22.7
# 89   7-Eleven     たんぱく質が摂れるチキン＆チリ     280.0       25.8    9.6     24.8
# 63   7-Eleven  スタミナ源たれソースのチキンバーガー     372.0       26.4   16.9     29.4
# 105  7-Eleven      うま塩ペッパーチキンバーガー     391.0       26.6   20.1     26.8
#
#      price_yen                                            url  \
# 132      390.0  https://www.sej.co.jp/products/a/item/052451/
# 55       390.0  https://www.sej.co.jp/products/a/item/053254/
# 89       400.0  https://www.sej.co.jp/products/a/item/053343/
# 63       380.0  https://www.sej.co.jp/products/a/item/053291/
# 105      350.0  https://www.sej.co.jp/products/a/item/053360/
#
#      protein_per_100kcal  protein_per_yen
# 132            11.428571         0.071795
# 55             11.428571         0.071795
# 89              9.214286         0.064500
# 63              7.096774         0.069474
# 105             6.803069         0.076000
#         store       product_name  calories  protein_g  fat_g  carbs_g  \
# 105  7-Eleven     うま塩ペッパーチキンバーガー     391.0       26.6   20.1     26.8
# 23   7-Eleven      トーストサンドハム＆チーズ     335.0       17.3   11.2     42.1
# 123  7-Eleven  ブリトーチーズ倍盛り　ハム＆チーズ     441.0       28.0   23.4     31.1
# 55   7-Eleven    たんぱく質が摂れるチキンロール     245.0       28.0    5.4     22.7
# 132  7-Eleven    たんぱく質が摂れるチキンロール     245.0       28.0    5.4     22.7
#
#      price_yen                                            url  \
# 105      350.0  https://www.sej.co.jp/products/a/item/053360/
# 23       238.0  https://www.sej.co.jp/products/a/item/051160/
# 123      390.0  https://www.sej.co.jp/products/a/item/053054/
# 55       390.0  https://www.sej.co.jp/products/a/item/053254/
# 132      390.0  https://www.sej.co.jp/products/a/item/052451/
#
#      protein_per_100kcal  protein_per_yen
# 105             6.803069         0.076000
# 23              5.164179         0.072689
# 123             6.349206         0.071795
# 55             11.428571         0.071795
# 132            11.428571         0.071795

# %% [markdown]
# This reveals some interesting facts about our dataset. Firstly, there are clearly duplicates among the sandwiches that we scraped off the Seven Eleven website. You will notice on the top table that the first two rows are the same product with the same values, just different URLs. This may be a mistake on Seven Eleven's part, or perhaps the products are separated based on region in which they are sold. In any case, further cleaning to get rid of perfect duplicates would make the dataset more precise.
#
# But as we can see, the **most calorie-efficient sandwich at Seven Eleven is the Chicken Roll** (たんぱく質が摂れるチキンロール) with **11.4 grams of protein per 100 calories**. At 245 calories for 28 grams of protein, it is an incredibly strong item, although that also seemd to drive the price up to 390 yen.
#
# If we look at the second table, we can see that **the most cost-effective item is the Salt and Pepper Chicken Burger** (うま塩ペッパーチキンバーガー). This is due to the good ratio of **26.6 grams of protein for 350 yen**, which is only 1.4 grams of protein less than the Chicken Roll, **but 40 yen cheaper**. However, when you note the calorie (391kcal vs 245kcal) and fat content (20.1g vs 5.4g) difference versus the Chicken Roll, perhaps the 40 yen is worth spending for the health-conscious consumer.

# %% [markdown]
# I put this small project together in about 3 hours of research, coding, and writing. It is far from what it could be, and I intend to expand on it with time and knowledge, but for now I hope that this is a good display of my foundational skills in data analysis. Thank you for reading.
